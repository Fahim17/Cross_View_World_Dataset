# %%
import pandas as pd

df = pd.read_csv(f'datasets/osv5m/test.csv')
df
# Out:
#                   id   latitude   longitude  \
# 33  2944946479124224  17.957809 -101.876156
# 34   489797689130214  23.253486   69.680438
# 35  1133509253779935  -3.763856   36.014861
# 36   189883882976069  11.878573  122.025287
# 37   263906548910300  40.136719  140.015891
# 38   431437561632755  55.604418   58.301792
#
#                                    thumb_original_url country  \
# 33  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      MX
# 34  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      IN
# 35  https://scontent-cdg4-3.xx.fbcdn.net/m1/v/t6/A...      TZ
# 36  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      PH
# 37  https://scontent-cdg4-1.xx.fbcdn.net/m1/v/t6/A...      JP
# 38  https://scontent-cdg4-3.xx.fbcdn.net/m1/v/t6/A...      RU
#
#                   sequence    captured_at  lon_bin  lat_bin      cell  ...  \
# 33  8nj1q9rs5yjae3d5zo2qcw  1523071170083       20       53  (20, 53)  ...
# ...

# %%
import os
import requests


def get_sat_img(id, lat, long, output_dir):
# ==== CONFIGURATION ====
    API_KEY = ""  # Replace with your API key
    OUTPUT_DIR = output_dir
    LATITUDE = lat
    LONGITUDE = long
    ZOOM = 20         # Zoom level: 0 (world) -> 21+ (building)
    IMAGE_SIZE = "640x640" # Max free tier size
    SCALE = 1              # 1=normal, 2=high-res (counts as more pixels)

    # ==== CREATE OUTPUT FOLDER ====
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    # ==== BUILD REQUEST URL ====
    url = (
        "https://maps.googleapis.com/maps/api/staticmap"
        f"?center={LATITUDE},{LONGITUDE}"
        f"&zoom={ZOOM}"
        f"&size={IMAGE_SIZE}"
        f"&scale={SCALE}"
        f"&maptype=satellite"
        f"&key={API_KEY}"
    )

    # ==== DOWNLOAD IMAGE ====
    response = requests.get(url)

    if response.status_code == 200:
        filename = os.path.join(OUTPUT_DIR, f"{id}.jpg")
        with open(filename, "wb") as f:
            f.write(response.content)
        # print(f"Saved satellite image: {filename}")
    else:
        print(f"Error {response.status_code}: {response.text}")

# %%
from tqdm import tqdm
strt_indx = 10000
img_num = 10000
output_dir = 'datasets/osv5m_sat/test'
os.makedirs(output_dir, exist_ok=True)

for i in tqdm(range(img_num)):
    id = df['id'].loc[strt_indx+i]
    lat = df['latitude'].loc[strt_indx+i]
    long = df['longitude'].loc[strt_indx+i]
    get_sat_img(id=id, lat=lat, long=long, output_dir=output_dir)
# Out:
#   0%|          | 21/10000 [00:07<55:28,  3.00it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 11
#       9 lat = df['latitude'].loc[strt_indx+i]
#      10 long = df['longitude'].loc[strt_indx+i]
# ---> 11 get_sat_img(id=id, lat=lat, long=long, output_dir=output_dir)
#
# Cell In[33], line 30, in get_sat_img(id, lat, long, output_dir)
#      19 url = (
#      20     "https://maps.googleapis.com/maps/api/staticmap"
#      21     f"?center={LATITUDE},{LONGITUDE}"
#    (...)
#      26     f"&key={API_KEY}"
#      27 )
#      29 # ==== DOWNLOAD IMAGE ====
# ---> 30 response = requests.get(url)
#      32 if response.status_code == 200:
#      33     filename = os.path.join(OUTPUT_DIR, f"{id}.jpg")
#
# File ~/.conda/envs/CVGL/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
# ...
